# %% [markdown]
# <a href="https://colab.research.google.com/github/saidjesus1923-ship-it/fundamento-2026/blob/main/Rendimiento_Extraccion_Aceite.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Control de Rendimiento en Extracción de Aceite**
# Este ejercicio es ideal para introducir float, int y la concatenación de strings.
#
# **Planteamiento:**
# Una planta procesadora de palma de aceite necesita calcular el **Índice de Rendimiento de Extracción (IRE).** El operario debe ingresar el peso total de los racimos de fruta fresca (RFF) procesados en kilogramos y la cantidad de aceite crudo obtenido en litros.
#
# **Requerimientos:**
#
# 1. Solicitar el nombre del lote de producción (Tipo string).
# 2. Solicitar el peso de los racimos en kg(Tipo float)(PR).
# 3. Solicitar los litros de aceite obtenidos (Tipo float)(LT).
# 4. Calcular el rendimiento sabiendo que la densidad aproximada del aceite es de 0.92 kg/L.(r)
#
# $$PA=LT×0.92$$
# $$r=(PA/PR)×100$$
#
# **Prueba del programa:**
#
# Si se ingresan 1000 kg de racimos y se obtienen 200 litros de aceite, el programa debe informar que el rendimiento del lote es del 18.4%.

# %%
from os import PRIO_PGRP
#ENTRADA# Solicitar el nombre del lote de producción (Tipo sting).
#Solicitar el peso de los racimos en kg(Tipo float)(PR)
#Solicitar los litros de aceite obtenidos (Tipo float)(LT)
NOMBRE=input("Ingrese el nombre del lote: ")
PR= float(input("ingrese el peso de los racimos en kg:"))
LT= float(input("ingrese los litros de aceite obtenidos:"))

#PROCESO calcular el peso del aceite (PA) y el rendimiento (r)
PA=LT*0.92
r=(PA/PR)*100

#SALIDA# Informar el rendimiento del lote
print("El rendimiento del lote",NOMBRE,"es del",r,"%")
# Out:
# Ingrese el nombre del lote: perico
# ingrese el peso de los racimos en kg:1000
# ingrese los litros de aceite obtenidos:200
# El rendimiento del lote perico es del 18.4 %

# %% [markdown]
# Aquí tienes la explicación de cada línea del código:
#
# ```python
# from os import PRIO_PGRP
# #ENTRADA# Solicitar el nombre del lote de producción (Tipo sting).
# #Solicitar el peso de los racimos en kg(Tipo float)(PR)
# #Solicitar los litros de aceite obtenidos (Tipo float)(LT)
# NOMBRE=input("Ingrese el nombre del lote: ")
# PR= float(input("ingrese el peso de los racimos en kg:"))
# LT= float(input("ingrese los litros de aceite obtenidos:"))
#
# #PROCESO calcular el peso del aceite (PA) y el rendimiento (r)
# PA=LT*0.92
# r=(PA/PR)*100
#
# #SALIDA# Informar el rendimiento del lote
# print("El rendimiento del lote",NOMBRE,"es del",r,"%")
# ```
#
# **Explicación línea a línea:**
#
# 1.  `from os import PRIO_PGRP`:
#     *   Esta línea importa la constante `PRIO_PGRP` del módulo `os`. El módulo `os` proporciona una forma de interactuar con el sistema operativo. En este contexto específico, `PRIO_PGRP` no se utiliza en el programa y podría ser una importación accidental o residual.
#
# 2.  `#ENTRADA# Solicitar el nombre del lote de producción (Tipo sting).`:
#     *   Este es un comentario (ignorada por Python) que sirve como una nota para el programador, indicando que las siguientes líneas de código se encargarán de solicitar la entrada de datos al usuario, específicamente el nombre del lote.
#
# 3.  `#Solicitar el peso de los racimos en kg(Tipo float)(PR)`:
#     *   Otro comentario que indica que se solicitará el peso de los racimos de fruta fresca (RFF) en kilogramos.
#
# 4.  `#Solicitar los litros de aceite obtenidos (Tipo float)(LT)`:
#     *   Otro comentario que indica que se solicitarán los litros de aceite crudo obtenidos.
#
# 5.  `NOMBRE=input("Ingrese el nombre del lote: ")`:
#     *   La función `input()` muestra el mensaje "Ingrese el nombre del lote: " al usuario y espera que este ingrese un texto. El texto ingresado se almacena como una cadena (string) en la variable `NOMBRE`.
#
# 6.  `PR= float(input("ingrese el peso de los racimos en kg:"))`:
#     *   Similar a la línea anterior, `input()` solicita al usuario el peso de los racimos en kg. El valor ingresado, que inicialmente es una cadena, se convierte a un número de punto flotante (`float`) usando `float()` y se guarda en la variable `PR`.
#
# 7.  `LT= float(input("ingrese los litros de aceite obtenidos:"))`:
#     *   De nuevo, `input()` pide los litros de aceite. El texto ingresado se convierte a `float` y se asigna a la variable `LT`.
#
# 8.  `#PROCESO calcular el peso del aceite (PA) y el rendimiento (r)`:
#     *   Un comentario que marca el inicio de la sección de procesamiento, donde se realizarán los cálculos.
#
# 9.  `PA=LT*0.92`:
#     *   Esta línea calcula el peso del aceite (`PA`). Multiplica la cantidad de aceite en litros (`LT`) por su densidad aproximada (0.92 kg/L). El resultado se almacena en la variable `PA`.
#
# 10. `r=(PA/PR)*100`:
#     *   Esta línea calcula el Índice de Rendimiento de Extracción (`r`). Divide el peso del aceite (`PA`) por el peso de los racimos (`PR`) y luego multiplica el resultado por 100 para expresarlo como un porcentaje. El valor final se guarda en la variable `r`.
#
# 11. `#SALIDA# Informar el rendimiento del lote`:
#     *   Un comentario que indica el comienzo de la sección de salida, donde se mostrarán los resultados.
#
# 12. `print("El rendimiento del lote",NOMBRE,"es del",r,"%")`:
#     *   Esta línea utiliza la función `print()` para mostrar el resultado al usuario. Concatena varias cadenas de texto junto con los valores de las variables `NOMBRE` y `r` para formar un mensaje legible que informa sobre el rendimiento del lote.
